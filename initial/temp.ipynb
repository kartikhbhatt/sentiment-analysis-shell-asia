# %%
from textblob import TextBlob
import pandas as pd

# %%
data = pd.read_csv('C:\\Users\\Kartik.Bhatt\\OneDrive - Shell\\Documents\\code playground\\initial\\code\\shell_asia_reviews_newest.csv')
data.head()
# Out:
#         userName       content  score  thumbsUpCount reviewCreatedVersion  \
# 0  A Google user            ok      5              0                1.2.5
# 1  A Google user  Good service      5              0                1.2.4
# 2  A Google user   Always best      5              0                1.2.5
# 3  A Google user         Great      5              0                1.2.5
# 4  A Google user      Perfecto      5              0                1.2.5
#
#                     at replyContent repliedAt appVersion
# 0  2025-02-24 08:27:42          NaN       NaN      1.2.5
# 1  2025-02-23 13:14:57          NaN       NaN      1.2.4
# 2  2025-02-23 11:44:36          NaN       NaN      1.2.5
# 3  2025-02-22 19:32:40          NaN       NaN      1.2.5
# 4  2025-02-22 16:08:13          NaN       NaN      1.2.5

# %%
def textblob_sentiment_analysis(review):
    # Analyzing the sentiment of the review
    sentiment = TextBlob(review).sentiment
    # Classifying based on polarity
    if sentiment.polarity > 0.1:
        return 'Positive'
    elif sentiment.polarity < -0.1:
        return 'Negative'
    else:
        return 'Neutral'

# Applying TextBlob sentiment analysis to the reviews
data['Sentiment'] = data['content'].apply(textblob_sentiment_analysis)

# Adding columns for polarity and subjectivity
data['Polarity'] = data['content'].apply(lambda review: TextBlob(review).sentiment.polarity)
data['Subjectivity'] = data['content'].apply(lambda review: TextBlob(review).sentiment.subjectivity)

# %%
# Displaying the first few rows with the sentiment, polarity, and subjectivity
data.head()
# Out:
#         userName       content  score  thumbsUpCount reviewCreatedVersion  \
# 0  A Google user            ok      5              0                1.2.5
# 1  A Google user  Good service      5              0                1.2.4
# 2  A Google user   Always best      5              0                1.2.5
# 3  A Google user         Great      5              0                1.2.5
# 4  A Google user      Perfecto      5              0                1.2.5
#
#                     at replyContent repliedAt appVersion Sentiment  Polarity  \
# 0  2025-02-24 08:27:42          NaN       NaN      1.2.5  Positive       0.5
# 1  2025-02-23 13:14:57          NaN       NaN      1.2.4  Positive       0.7
# 2  2025-02-23 11:44:36          NaN       NaN      1.2.5  Positive       1.0
# 3  2025-02-22 19:32:40          NaN       NaN      1.2.5  Positive       0.8
# 4  2025-02-22 16:08:13          NaN       NaN      1.2.5   Neutral       0.0
#
#    Subjectivity
# 0          0.50
# 1          0.60
# 2          0.30
# 3          0.75
# 4          0.00
